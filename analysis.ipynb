# %% [markdown]
# <a href="https://colab.research.google.com/github/palamarchuknadiia23-droid/python-analytics-homework/blob/main/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {"city": ["Kyiv", "Lviv", "Odesa"], "sales": [1200, 900, 500]}
df = pd.DataFrame(data)
print("Продажі по містах:")
print(df)
print("Середнє значення:", df["sales"].mean())
# Out:
# Продажі по містах:
#     city  sales
# 0   Kyiv   1200
# 1   Lviv    900
# 2  Odesa    500
# Середнє значення: 866.6666666666666
